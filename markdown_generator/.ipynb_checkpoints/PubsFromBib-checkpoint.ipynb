# %% [markdown]
# # Publications markdown generator for academicpages
#
# Takes a set of bibtex of publications and converts them for use with [academicpages.github.io](academicpages.github.io). This is an interactive Jupyter notebook ([see more info here](http://jupyter-notebook-beginner-guide.readthedocs.io/en/latest/what_is_jupyter.html)).
#
# The core python code is also in `pubsFromBibs.py`.
# Run either from the `markdown_generator` folder after replacing updating the publist dictionary with:
# * bib file names
# * specific venue keys based on your bib file preferences
# * any specific pre-text for specific files
# * Collection Name (future feature)
#
# TODO: Make this work with other databases of citations,
# TODO: Merge this with the existing TSV parsing solution

# %%
from pybtex.database.input import bibtex
import pybtex.database.input.bibtex 
from time import strptime
import string
import html
import os
import re

# %%
#todo: incorporate different collection types rather than a catch all publications, requires other changes to template
publist = {
      'article' : {'tatum2018pi',
      'title' : '$\pi$-Conjugated polymer nanowires: advances and perspectives toward effective commercial implementation',
      'author' : {Tatum, Wesley K and Luscombe, Christine K},
      journal={Polymer Journal},
      volume={50},
      number={8},
      pages={659--669},
      year={2018},
      publisher={Nature Publishing Group}
    },

      article{xi2018sonocrystallization,
      title={Sonocrystallization of conjugated polymers with ultrasound fields},
      author={Xi, Yuyin and Li, David S and Newbloom, Greg M and Tatum, Wesley K and O’Donnell, Matthew and Luscombe, Christine K and Pozzo, Lilo D},
      journal={Soft matter},
      volume={14},
      number={24},
      pages={4963--4976},
      year={2018},
      publisher={Royal Society of Chemistry}
    },

      article{shi2018direct,
      title={The Direct Arylation Polymerization (DArP) of Well-Defined Alternating Copolymers Based On 5, 6-Dicyano [2, 1, 3] benzothiadiazole (DCBT)},
      author={Shi, Qinqin and Tatum, Wesley and Zhang, Junxiang and Scott, Colleen and Luscombe, Christine K and Marder, Seth R and Blakey, Simon B},
      journal={Asian Journal of Organic Chemistry},
      volume={7},
      number={7},
      pages={1419--1425},
      year={2018},
      publisher={Wiley Online Library}
    },

      article{li2018low,
      title={Low elastic modulus and high charge mobility of low-crystallinity indacenodithiophene-based semiconducting polymers for potential applications in stretchable electronics},
      author={Li, Yilin and Tatum, Wesley K and Onorato, Jonathan W and Zhang, Yongcao and Luscombe, Christine K},
      journal={Macromolecules},
      volume={51},
      number={16},
      pages={6352--6358},
      year={2018},
      publisher={ACS Publications}
    },

      inproceedings{li2017indacenodithiophene,
      title={Indacenodithiophene-based semiconducting polymers for stretchable organic electronics},
      author={Li, Yilin and Tatum, Wesley and Onorato, Jonathan and Barajas, Sierra and Yang, Yun and Luscombe, Christine},
      booktitle={ABSTRACTS OF PAPERS OF THE AMERICAN CHEMICAL SOCIETY},
      volume={254},
      year={2017},
      organization={AMER CHEMICAL SOC 1155 16TH ST, NW, WASHINGTON, DC 20036 USA}
    }

      article{keerthisinghe2019pv,
      title={PV-Battery Systems for Critical Loads During Emergencies: A Case Study from Puerto Rico After Hurricane Maria},
      author={Keerthisinghe, Chanaka and Ahumada-Paras, Mareldi and Pozzo, Lilo D and Kirschen, Daniel S and Pontes, Hugo and Tatum, Wesley K and Matos, Marvi A},
      journal={IEEE Power and Energy Magazine},
      volume={17},
      number={1},
      pages={82--92},
      year={2019},
      publisher={IEEE}
    },

      article{li2017indacenodithiophene,
      title={An indacenodithiophene-based semiconducting polymer with high ductility for stretchable organic electronics},
      author={Li, Yilin and Tatum, Wesley K and Onorato, Jonathan W and Barajas, Sierra D and Yang, Yun Young and Luscombe, Christine K},
      journal={Polymer Chemistry},
      volume={8},
      number={34},
      pages={5185--5193},
      year={2017},
      publisher={Royal Society of Chemistry}
    },

      article{tatum2019defect,
      title={Defect Tolerance of $\pi$-Conjugated Polymer Crystal Lattices and Their Relevance to Optoelectronic Applications},
      author={Tatum, Wesley K and Resing, Anton B and Flagg, Lucas Q and Ginger, David S and Luscombe, Christine K},
      journal={ACS Applied Polymer Materials},
      volume={1},
      number={6},
      pages={1466--1475},
      year={2019},
      publisher={American Chemical Society}
    },

      article{tatum2020generalizable,
      title={A Generalizable Framework for Algorithmic Interpretation of Thin Film Morphologies in Scanning Probe Images},
      author={Tatum, Wesley and Torrejon, Diego and O'Neil, Patrick and Onorato, Jonathan W and Resing, Anton and Holliday, Sarah and Flagg, Lucas Q and Ginger, David S and Luscombe, Christine K},
      journal={Journal of Chemical Information and Modeling},
      year={2020},
      publisher={American Chemical Society}
    },

      article{sommerville2020elucidating,
      title={Elucidating the Influence of Side-Chain Circular Distribution on the Crack Onset Strain and Hole Mobility of Near-Amorphous Indacenodithiophene Copolymers},
      author={Sommerville, Parker JW and Li, Yilin and Dong, Ban Xuan and Zhang, Yongcao and Onorato, Jonathan W and Tatum, Wesley K and Balzer, Alex H and Stingelin, Natalie and Patel, Shrayesh N and Nealey, Paul F and others},
      journal={Macromolecules},
      volume={53},
      number={17},
      pages={7511--7518},
      year={2020},
      publisher={American Chemical Society}
    },

      phdthesis{tatum2020establishing,
      title={Establishing Quantitative Relationships Between Composition, Morphology, and Performance in Polymer Electronics},
      author={Tatum, Wesley K},
      year={2020}
    },
    
      article{haydon2018,
      title={Workforce diversity: Strategies for cultivating inclusion in research},
      author={Haydon, Ian and Herpoldt, Karla-Louise and Hosseinzadeh, Parisa and Kang, Christine and Kang, Lauren J and Montoni, Nicholas P and Tatum, Wesley K},
      journal={Inside eLife},
      year={2018},
      publisher={eLife sciences Publications},
      url={https://elifesciences.org/inside-elife/8a24d01a/workforce-diversity-strategies-for-cultivating-inclusion-in-research}
}
# Out:
#   File "<ipython-input-5-0d62e4d350bf>", line 3
#     article{tatum2018pi,
#            ^
# SyntaxError: invalid syntax

# %%
html_escape_table = {
    "&": "&amp;",
    '"': "&quot;",
    "'": "&apos;"
    }

def html_escape(text):
    """Produce entities within text."""
    return "".join(html_escape_table.get(c,c) for c in text)

# %%
for pubsource in publist:
    parser = bibtex.Parser()
    bibdata = parser.parse_file(publist[pubsource]["file"])

    #loop through the individual references in a given bibtex file
    for bib_id in bibdata.entries:
        #reset default date
        pub_year = "1900"
        pub_month = "01"
        pub_day = "01"
        
        b = bibdata.entries[bib_id].fields
        
        try:
            pub_year = f'{b["year"]}'

            #todo: this hack for month and day needs some cleanup
            if "month" in b.keys(): 
                if(len(b["month"])<3):
                    pub_month = "0"+b["month"]
                    pub_month = pub_month[-2:]
                elif(b["month"] not in range(12)):
                    tmnth = strptime(b["month"][:3],'%b').tm_mon   
                    pub_month = "{:02d}".format(tmnth) 
                else:
                    pub_month = str(b["month"])
            if "day" in b.keys(): 
                pub_day = str(b["day"])

                
            pub_date = pub_year+"-"+pub_month+"-"+pub_day
            
            #strip out {} as needed (some bibtex entries that maintain formatting)
            clean_title = b["title"].replace("{", "").replace("}","").replace("\\","").replace(" ","-")    

            url_slug = re.sub("\\[.*\\]|[^a-zA-Z0-9_-]", "", clean_title)
            url_slug = url_slug.replace("--","-")

            md_filename = (str(pub_date) + "-" + url_slug + ".md").replace("--","-")
            html_filename = (str(pub_date) + "-" + url_slug).replace("--","-")

            #Build Citation from text
            citation = ""

            #citation authors - todo - add highlighting for primary author?
            for author in bibdata.entries[bib_id].persons["author"]:
                citation = citation+" "+author.first_names[0]+" "+author.last_names[0]+", "

            #citation title
            citation = citation + "\"" + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + ".\""

            #add venue logic depending on citation type
            venue = publist[pubsource]["venue-pretext"]+b[publist[pubsource]["venuekey"]].replace("{", "").replace("}","").replace("\\","")

            citation = citation + " " + html_escape(venue)
            citation = citation + ", " + pub_year + "."

            
            ## YAML variables
            md = "---\ntitle: \""   + html_escape(b["title"].replace("{", "").replace("}","").replace("\\","")) + '"\n'
            
            md += """collection: """ +  publist[pubsource]["collection"]["name"]

            md += """\npermalink: """ + publist[pubsource]["collection"]["permalink"]  + html_filename
            
            note = False
            if "note" in b.keys():
                if len(str(b["note"])) > 5:
                    md += "\nexcerpt: '" + html_escape(b["note"]) + "'"
                    note = True

            md += "\ndate: " + str(pub_date) 

            md += "\nvenue: '" + html_escape(venue) + "'"
            
            url = False
            if "url" in b.keys():
                if len(str(b["url"])) > 5:
                    md += "\npaperurl: '" + b["url"] + "'"
                    url = True

            md += "\ncitation: '" + html_escape(citation) + "'"

            md += "\n---"

            
            ## Markdown description for individual page
            if note:
                md += "\n" + html_escape(b["note"]) + "\n"

            if url:
                md += "\n[Access paper here](" + b["url"] + "){:target=\"_blank\"}\n" 
            else:
                md += "\nUse [Google Scholar](https://scholar.google.com/scholar?q="+html.escape(clean_title.replace("-","+"))+"){:target=\"_blank\"} for full citation"

            md_filename = os.path.basename(md_filename)

            with open("../_publications/" + md_filename, 'w') as f:
                f.write(md)
            print(f'SUCESSFULLY PARSED {bib_id}: \"', b["title"][:60],"..."*(len(b['title'])>60),"\"")
        # field may not exist for a reference
        except KeyError as e:
            print(f'WARNING Missing Expected Field {e} from entry {bib_id}: \"', b["title"][:30],"..."*(len(b['title'])>30),"\"")
            continue
